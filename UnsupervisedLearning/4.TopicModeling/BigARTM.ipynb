# %% [markdown]
# # Тематическая модель [Постнауки](http://postnauka.ru)
# ## Peer Review (optional)

# %% [markdown]
# В этом задании мы применим аппарат тематического моделирования к коллекции текстовых записей видеолекций, скачанных с сайта Постнаука. Мы будем визуализировать модель и создавать прототип тематического навигатора по коллекции. В коллекции 1728 документов, размер словаря - 38467 слов. Слова лемматизированы, то есть приведены к начальной форме, с помощью программы [mystem](https://tech.yandex.ru/mystem/), коллекция сохранена в [формате vowpal wabbit](http://docs.bigartm.org/en/latest/formats.html). В каждой строке до первой черты записана информация о документе (ссылка на страницу с лекцией), после первой черты следует описание документа. Используются две модальности - текстовая ("text") и модальность авторов ("author"); у каждого документа один автор.

# %% [markdown]
# Для выполнения задания понадобится библиотека [BigARTM](http://docs.bigartm.org). В демонстрации показан пример использования библиотеки версии 0.9.0. В новой версии изменены принципы работы со словарями: они вынесены в отдельный класс (пример в [Release Notes](http://docs.bigartm.org/en/stable/release_notes/python.html)).
#
# Спецификации всех функций вы можете смотреть на странице [Python API](http://bigartm.readthedocs.io/en/stable/python_interface.html).

# %%
import artm

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline
seaborn.set_style("whitegrid", {'axes.grid' : False})
plt.style.use("seaborn")

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Считывание данных

# %% [markdown]
# Создайте объект класса artm.BatchVectorizer, который будет ссылаться на директорию с пакетами данных (батчами). Чтобы библиотека могла преобразовать текстовый файл в батчи, создайте пустую директорию и укажите ее название в параметре target_folder. Размер батча для небольших коллекций (как наша) не важен, вы можете указать любой.

# %%
batch_vectorizer = artm.BatchVectorizer(
    data_path="./data/lectures.txt",
    data_format="vowpal_wabbit",
    target_folder="./data/lectures_batches", 
    batch_size=100
)

# %% [markdown]
# ##### Инициализация модели

# %% [markdown]
# Создайте объект класса artm.Model с 30 темами, именами тем, указанными ниже и единичными весами обеих модальностей. Количество тем выбрано не очень большим, чтобы вам было удобнее работать с темами. На этой коллекции можно строить и большее число тем, тогда они будут более узко специализированы.

# %%
T = 30   # количество тем
topic_names=["sbj"+str(i) for i in range(T-1)]+["bcg"]

model_artm = artm.ARTM(
    num_topics=T,
    topic_names=topic_names,
    class_ids={"text":1, "author": 1},
    num_document_passes=1,
    cache_theta=True,
    seed=-1,
)

# %% [markdown]
# Мы будем строить 29 предметных тем и одну фоновую.
#
# Соберите словарь с помощью метода gather_dictionary и инициализируйте модель, указав random_seed=1. Обязательно укажите свое название словаря, оно понадобится при добавлении регуляризаторов.

# %%
dictionary = artm.Dictionary(name='dictionary')
dictionary.gather(batch_vectorizer.data_path)

# %%
model_artm.initialize(dictionary=dictionary)

# %% [markdown]
# ##### Добавление score

# %% [markdown]
# Создайте два измерителя качества artm.TopTokensScore - по одному для каждой модальности; количество токенов 15. Названия для score придумайте самостоятельно.

# %%
model_artm.scores.add(artm.TopTokensScore(name="top_words_text", num_tokens=15, class_id="text"))
model_artm.scores.add(artm.TopTokensScore(name="top_words_author", num_tokens=15, class_id="author"))

# %% [markdown]
# ##### Построение модели

# %% [markdown]
# Мы будем строить модель в два этапа: сначала добавим сглаживающий регуляризатор фоновой темы и настроим параметры модели, затем - добавим разреживающий регуляризатор предметрых тем и выполним еще несколько итераций. Так мы сможем получить наиболее чистые от фоновых слов предметные темы. Сглаживающий и разреживающий регуляризаторы задаются одним и тем же классом artm.SmoothSparsePhiRegularizer: если коэффициент tau положительный, то регуляризатор будет сглаживающий, если отрицательный - разреживающий.
#
# Если вы хотите подробнее разобраться, как выполняется регуляризация тематической модели в BigARTM, вы можете прочитать [статью](https://s3-eu-west-1.amazonaws.com/artm/voron-potap14artm-rus.pdf), раздел 4.

# %% [markdown]
# Добавьте сглаживающий регуляризатор с коэффициентом tau = 1e5, указав название своего словаря в dictionary, модальность текста в class_ids и тему "bcg" в topic_names.

# %%
SSR = artm.SmoothSparsePhiRegularizer(
    name='SparsePhi',
    tau=1000,
    class_ids="text",
    topic_names="bcg"
)
SSR.dictionary_name = "dictionary"
model_artm.regularizers.add(SSR)

# %% [markdown]
# Выполните 30 итераций по коллекции (num_collection_passes), количество внутренних итераций установите равным 1. Используйте метод fit_offline модели.

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=30)

# %% [markdown]
# Добавьте разреживающий регуляризатор с коэффициентом tau=-1e5, указав название своего словаря, модальность текста в class_ids и все темы "sbjX" в topic_names.

# %%
SSR = artm.SmoothSparsePhiRegularizer(
    name='SparsePhi2',
    tau=-100,
    class_ids="text",
    topic_names=topic_names[:-1]

)
SSR.dictionary_name = "dictionary"
model_artm.regularizers.add(SSR)

# %% [markdown]
# Выполните еще 15 проходов по коллекции.

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

# %% [markdown]
# ##### Интерпретация тем

# %% [markdown]
# Используя созданные score, выведите топы слов и топы авторов в темах. Удобнее всего выводить топ слов каждой темы с новой строки, указывая название темы в начале строки, и аналогично с авторами.

# %%
for topic_name in model_artm.topic_names:
    print(topic_name + ': ', end=" ")
    for word in model_artm.score_tracker["top_words_text"].last_tokens[topic_name]:
        print(word, end=" ")
    print()
# Out:
# sbj0:  свой быть его русский конечно век отношение власть александр писать написать имя историк римский король
# sbj1:  очень много поэтому такой там что раз интересный находиться высокий земля планета элемент условие тело
# sbj2:  такой система чтобы один между этот создавать общий сложный простой движение трудность
# sbj3:  как что начинать современный где себя сторона чем говорить это возникать другой когда
# sbj4:  если должный даже вид один появляться давать каждый это себя или любой вещь иной функция
# sbj5:  быть можно при получать структура сделать достаточно использовать материал свойство для пора применение углерод электронный
# sbj6:  она быть что говорить потому этот книга научный как выходить тема автор фильм
# sbj7:  тот человек именно сам который социальный после общество знание принимать степень род социология смерть социологический
# sbj8:  какой наука новый рассказывать процесс как доктор различный это связь каков развиваться использоваться наиболее химический
# sbj9:  теория оказываться частица состояние взаимодействие пространство три поле состоять описывать квантовый эксперимент явление физика сила
# sbj10:  быть год уже первый все момент потом конец это тот становиться робот
# sbj11:  этот время более человек что такой почему случай они быть пациент
# sbj12:  который мочь происходить они работать область мозг изменение механизм среда эволюция вода нейрон растение ткань
# sbj13:  который этот существовать быть часть они основной место город кандидат жить период изучение территория центр
# sbj14:  видеть несколько звезда объект большой энергия галактика масса вещество примерно свет источник маленький черный волна
# sbj15:  когда самый какой-то что просто все что-то информация мочь чем данные хороший внимание они
# sbj16:  они быть еще очень большой тоже довольно потому группа два менее практически кроме лицо самый
# sbj17:  политический кто право понятие россия идея государство война страна советский философия закон революция российский политика
# sbj18:  что например разный слово знать понимать два если вот оно вообще это значение речь взять
# sbj19:  что как становиться дело вопрос жизнь друг ситуация школа
# sbj20:  весь это только для важный который возникать все этот технология сегодня так
# sbj21:  или это наш проблема мочь какой-то либо ребенок память только женщина семья операция врач
# sbj22:  другой так называть некоторый сказать нет этот смысл представлять форма число правило быть описание
# sbj23:  это что задача модель мочь исследование быть очень решать этот сообщество схема какой
# sbj24:  мир история культура век текст начало исторический представление древний традиция народ эпоха литература бог христианский
# sbj25:  быть язык иметь который один называться многий особенность программа английский позиция лингвист
# sbj26:  который этот как образ развитие определенный решение роль уровень что поведение экономический психология экономика выбор
# sbj27:  клетка организм ген днк белок молекула биологический животное болезнь заболевание генетический это живой геном медицина
# sbj28:  для являться этот сейчас работа метод количество точка принцип возможность ученый основа направление который также
# bcg:  нужно делать здесь связывать тип хорошо позволять далее совершенно идти результат показывать второй находить связанный

# %% [markdown]
# В последней теме "bcg" должны находиться общеупотребительные слова.
#
# Важный шаг в работе с тематической моделью, когда речь идет о визуализации или создании тематического навигатора, это именование тем. Понять, о чем каждая тема, можно по списку ее топовых слов. Например, тему
#
#     частица взаимодействие физика кварк симметрия элементарный нейтрино стандартный материя протон бозон заряд масса ускоритель слабый
#
# можно назвать "Физика элементарных частиц".
#
# Дайте названия 29 предметным темам. Если вы не знаете, как назвать тему, назовите ее первым встретившимся в ней существительным, хотя при таком подходе навигатор будет менее информативным. Из названий тем составьте список из 29 строк и запишите го в переменную sbj_topic_labels. В переменной topic_labels будут храниться названия всех тем, включая фоновую.

# %%
sbj_topic_labels = [
    "История",
    "Астрономия",
    "Кинематика",
    "Начинания",
    "Виды",
    "Физика углеродных частиц",
    "Литература",
    "Социология",
    "Химия",
    "Физика поля",
    "Робот",
    "Пациент",
    "Эволюция",
    "Кандидат",
    "Космос",
    "Информация",
    "Группа",
    "Политика",
    "Речь",
    "Школа",
    "Технологии",
    "Семейные проблемы",
    "Форма",
    "Задача",
    "История религии",
    "Лингвистика",
    "Психология",
    "Биология",
    "Разработка",
]
topic_labels = sbj_topic_labels + ["Фоновая тема"]
topics_dict = dict(zip(topic_names, topic_labels))

# %%
print(len(topic_labels))
# Out:
# 30

# %% [markdown]
# ##### Анализ тем

# %%
topics_dict
# Out:
# {'sbj0': 'История',
#  'sbj1': 'Астрономия',
#  'sbj2': 'Кинематика',
#  'sbj3': 'Начинания',
#  'sbj4': 'Виды',
#  'sbj5': 'Физика углеродных частиц',
#  'sbj6': 'Литература',
#  'sbj7': 'Социология',
#  'sbj8': 'Химия',
#  'sbj9': 'Физика поля',
#  'sbj10': 'Робот',
#  'sbj11': 'Пациент',
#  'sbj12': 'Эволюция',
#  'sbj13': 'Кандидат',
#  'sbj14': 'Космос',
#  'sbj15': 'Информация',
#  'sbj16': 'Группа',
#  'sbj17': 'Политика',
#  'sbj18': 'Речь',
#  'sbj19': 'Школа',
#  'sbj20': 'Технологии',
#  'sbj21': 'Семейные проблемы',
#  'sbj22': 'Форма',
#  'sbj23': 'Задача',
#  'sbj24': 'История религии',
#  'sbj25': 'Лингвистика',
#  'sbj26': 'Психология',
#  'sbj27': 'Биология',
#  'sbj28': 'Разработка',
#  'bcg': 'Фоновая тема'}

# %% [markdown]
# Далее мы будем работать с распределениями тем в документах (матрица $\Theta$) и авторов в темах (одна из двух матриц $\Phi$, соответствующая модальности авторов).
# Создайте переменные, содержащие две этих матрицы, с помощью методов get_phi и get_theta модели. Назовите переменные theta и phi_a. Выведите формы обеих матриц, чтобы понять, по каким осям стоят темы.

# %%
model_artm.theta_columns_naming = "title" # включает именование столбцов Theta их названиями-ссылками, а не внутренними id 
phi_a = model_artm.get_phi(class_ids="author")
theta = model_artm.get_theta()

# %%
phi_a
# Out:
#                             sbj0          sbj1          sbj2          sbj3  \
# Александр_Четверин  0.000000e+00  0.000000e+00  2.430324e-10  0.000000e+00
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     0.000000e+00  0.000000e+00  3.631427e-07  2.492523e-15
# Галина_Ершова       0.000000e+00  0.000000e+00  1.671648e-09  2.960172e-12
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    0.000000e+00  0.000000e+00  0.000000e+00  1.694812e-16
# Иван_Болдырев       8.863763e-13  0.000000e+00  3.502526e-07  6.011403e-05
# Кирилл_Разлогов     0.000000e+00  2.359337e-16  4.110550e-12  3.699695e-06
#
#                             sbj4          sbj5          sbj6          sbj7  \
# Александр_Четверин  3.550547e-14  1.341664e-02  8.532754e-14  0.000000e+00
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     4.843633e-15  0.000000e+00  1.181433e-14  0.000000e+00
# Галина_Ершова       0.000000e+00  1.575471e-16  1.794344e-15  0.000000e+00
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    3.729527e-16  0.000000e+00  1.376835e-16  8.373510e-02
# Иван_Болдырев       1.333018e-07  7.909337e-13  3.144556e-04  8.752134e-08
# Кирилл_Разлогов     9.708191e-09  3.954142e-15  1.501707e-08  2.498720e-10
#
#                             sbj8      sbj9  ...         sbj20         sbj21  \
# Александр_Четверин  3.043732e-05  0.000000  ...  7.189442e-13  5.045514e-10
# Сергей_Деев         1.458348e-02  0.000000  ...  3.109168e-14  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.010587  ...  0.000000e+00  0.000000e+00
# Николай_Борисов     1.936943e-06  0.000000  ...  1.121914e-11  5.433083e-06
# sbj2                          0.026509                         0.024465
# sbj3                          0.019720                         0.020162
# sbj4                          0.017154                         0.023134
# sbj5                          0.035996                         0.021944
# sbj6                          0.016960                         0.015515
# sbj7                          0.014781                         0.034269
# sbj8                          0.024531                         0.013812
# sbj9                          0.008938                         0.004590
# sbj10                         0.021105                         0.007526
# sbj11                         0.013224                         0.011878
# sbj12                         0.028358                         0.016760
# sbj13                         0.016462                         0.016513
# sbj14                         0.019424                         0.005616
# sbj15                         0.026872                         0.012607
# sbj16                         0.019269                         0.009629
# sbj17                         0.000994                         0.017228
# sbj18                         0.017829                         0.028787
# sbj19                         0.017433                         0.029214
# sbj20                         0.016214                         0.022545
# sbj21                         0.024680                         0.016800
# sbj22                         0.014892                         0.014268
# sbj23                         0.016977                         0.016126
# sbj24                         0.003958                         0.009190
# sbj25                         0.013938                         0.012112
# sbj26                         0.021291                         0.026216
# sbj27                         0.074066                         0.000209
# sbj28                         0.022937                         0.025981
# bcg                           0.414430                         0.518753
#
#        http://postnauka.ru/video/50349  http://postnauka.ru/video/50350
# sbj0                          0.009640                         0.057097
# sbj1                          0.022331                         0.022368
# sbj2                          0.032577                         0.011100
# sbj3                          0.016937                         0.014229
# sbj4                          0.021816                         0.014870
# sbj5                          0.040157                         0.020259
# sbj6                          0.017552                         0.015678
# sbj7                          0.022542                         0.013985
# sbj8                          0.014334                         0.009515
# sbj9                          0.008471                         0.002276
# sbj10                         0.022123                         0.038725
# sbj11                         0.018879                         0.012168
# sbj12                         0.020149                         0.014461
# sbj13                         0.012671                         0.015724
# sbj14                         0.012156                         0.010675
# sbj15                         0.070482                         0.015705
# sbj16                         0.020185                         0.018189
# sbj17                         0.008509                         0.009099
# sbj18                         0.008474                         0.015650
# sbj19                         0.015789                         0.012968
# sbj20                         0.021893                         0.006419
# sbj21                         0.039120                         0.004175
# sbj22                         0.014980                         0.014823
# sbj23                         0.018478                         0.006949
# sbj24                         0.001891                         0.040321
# sbj25                         0.019927                         0.017541
# sbj26                         0.016182                         0.020357
# sbj27                         0.001344                         0.000207
# sbj28                         0.031893                         0.005349
# bcg                           0.418519                         0.539118
#
# [30 rows x 1728 columns]

# %% [markdown]
# Визуализируем фрагмент матрицы $\Theta$ - первые 100 документов (это наиболее простой способ визуально оценить, как темы распределяются в документах). С помощью метода seaborn.heatmap выведите фрагмент theta как изображение. Рекомендация: создайте фигуру pyplot размера (20, 10).

# %%
plt.figure(figsize=(20, 10))
seaborn.heatmap(data=theta.iloc[:,:100], cmap='YlGnBu')
plt.show()

# %% [markdown]
# Вы должны увидеть, что фоновая тема имеет большую вероятность в почти каждом документе, и это логично. Кроме того, есть еще одна тема, которая чаще других встречается в документах. Судя по всему, это тема содержит много слов по науку в целом, а каждый документ (видео) в нашей коллекции связан с наукой. Можно (необязательно) дать этой теме название "Наука".
#
# Помимо этих двух тем, фоновой и общенаучной, каждый документ характеризуется малым числом других тем.

# %% [markdown]
# Оценим $p(t)$ - долю каждой темы во всей коллекции. По формуле полной вероятности вычислять эти величины нужно как
# $p(t) = \sum_d p(t|d) p(d)$. Согласно вероятностной модели, $p(d)$ пропорционально длине документа d. Поступим проще: будем полагать, что все документы равновероятны. Тогда оценить $p(t)$ можно, просуммировав $p(t|d)$ по всем документам, а затем разделив полученный вектор на его сумму.
#
# Создайте переменную-датафрейм с T строками, индексированными названиями тем, и 1 столбцом, содержащим оценки $p(t)$. Выведите датафрейм на печать.

# %%
pt = pd.DataFrame(theta.sum(axis=1))
pt
# Out:
#                 0
# sbj0    26.198532
# sbj1    31.524466
# sbj2    26.487547
# sbj3    35.836452
# sbj4    30.096607
# sbj5    30.205622
# sbj6    27.727449
# sbj7    30.000689
# sbj8    76.148033
# sbj9    37.187412
# sbj10   26.529984
# sbj11   26.579119
# sbj12   32.457088
# sbj13   40.354862
# sbj14   38.149258
# sbj15   28.941801
# sbj16   27.223545
# sbj17   29.572693
# sbj18   29.278843
# sbj19   28.941790
# sbj20   30.106226
# sbj21   29.450609
# sbj22   29.067966
# sbj23   34.009544
# sbj24   33.271408
# sbj25   29.434225
# sbj26   33.757290
# sbj27   25.406666
# sbj28   34.714787
# bcg    789.339661

# %% [markdown]
# Найдите 5 самых распространенных и 3 наименее освещенных темы в коллекции (наибольшие и наименьшие $p(t)$ соответственно), не считая фоновую и общенаучную. Укажите названия, которые вы дали этим темам.

# %%
print("Most popular topics:\n")
for sub, score in list(theta.sum(axis=1).sort_values(ascending=False)[:6].items()):
    print(f"sub: {topics_dict[sub]}")
    print(f"score: {score}")
    print(f"---")
# Out:
# Most popular topics:
#
# sub: Фоновая тема
# score: 789.3396606445312
# ---
# sub: Химия
# score: 76.14803314208984
# ---
# sub: Кандидат
# score: 40.354862213134766
# ---
# sub: Космос
# score: 38.14925765991211
# ---
# sub: Физика поля
# score: 37.18741226196289
# ---
# sub: Начинания
# score: 35.83645248413086
# ---

# %%
print("Least popular topics:\n")
for sub, score in list(theta.sum(axis=1).sort_values()[:3].items()):
    print(f"sub: {topics_dict[sub]}")
    print(f"score: {score}")
    print(f"---")
# Out:
# Least popular topics:
#
# sub: Биология
# score: 25.406665802001953
# ---
# sub: История
# score: 26.198532104492188
# ---
# sub: Кинематика
# score: 26.487546920776367
# ---

# %% [markdown]
# Визуализируйте матрицу $\Phi$ модальности авторов в виде изображения. Рекомендация: установите yticklabels=False в heatmap.

# %%
plt.figure(figsize=(20, 15))
seaborn.heatmap(data=phi_a, cmap='YlGnBu')
plt.show()

# %% [markdown]
# Каждой теме соответствует не очень большое число авторов - матрица достаточно разреженная. Кроме того, некоторые темы имеют доминирующего автора $a$, имеющего большую вероятность $p(a|t)$ - этот автор записал больше всего лекций по теме.

# %% [markdown]
# Будем считать, что автор $a$ значим в теме, если $p(a|t) > 0.01$. Для каждого автора посчитайте, в скольких темах он значим. Найдите авторов-рекордсменов, которые значимы (а значит, читали лекции) в >= 3 темах.

# %%
pd.DataFrame(phi_a[phi_a > 0.01].count(axis=1)[phi_a[phi_a > 0.01].count(axis=1) >= 3])
# Out:
#                     0
# Кирилл_Мартынов     3
# Борис_Миркин        3
# Гасан_Гусейнов      3
# Сергей_Киселев      3
# Михаил_Соколов      3
# Александр_Филиппов  3
# Мануэль_Маццара     3

# %% [markdown]
# Большинство авторов значимы в 1 теме, что логично.

# %% [markdown]
# ##### Построение тематической карты авторов

# %% [markdown]
# По сути, в матрице $\Phi$, соответствующей модальности авторов, записаны тематические кластеры авторов. Для любого автора мы можем составить его тематический круг - авторов, разбирающихся в той же теме, что и данный. Интересующиеся слушатели могут попробовать выполнить эту процедуру для ученых, читающих лекции на Постнауке, которых они знают (например, на Постнауке есть лекции с К. В. Воронцовым - лектором текущего модуля :)
#
# Составим карту близости авторов по тематике их исследований. Для этого применим метод понижения размерности MDS к тематическим профилям авторов.
#
# Чтобы получить тематический профиль автора, распределение $p(t|a)$, нужно воспользоваться формулой Байеса:
# $p(t|a) = \frac {p(a|t) p(t)} {\sum_t' p(a|t') p(t')}$. Все необходимые для этого величины у вас есть и записаны в переменных phi и pt.
#
# Передайте матрицу тематических профилей авторов, записанных по строкам, в метод MDS с n_components=2. Используйте косинусную метрику (она хорошо подходит для поиска расстояний между векторами, имеющими фиксированную сумму компонент).

# %%
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances

# %%
pt
# Out:
#                 0
# sbj0    26.198532
# sbj1    31.524466
# sbj2    26.487547
# sbj3    35.836452
# sbj4    30.096607
# sbj5    30.205622
# sbj6    27.727449
# sbj7    30.000689
# sbj8    76.148033
# sbj9    37.187412
# sbj10   26.529984
# sbj11   26.579119
# sbj12   32.457088
# sbj13   40.354862
# sbj14   38.149258
# sbj15   28.941801
# sbj16   27.223545
# sbj17   29.572693
# sbj18   29.278843
# sbj19   28.941790
# sbj20   30.106226
# sbj21   29.450609
# sbj22   29.067966
# sbj23   34.009544
# sbj24   33.271408
# sbj25   29.434225
# sbj26   33.757290
# sbj27   25.406666
# sbj28   34.714787
# bcg    789.339661

# %%
phi_a
# Out:
#                             sbj0          sbj1          sbj2          sbj3  \
# Александр_Четверин  0.000000e+00  0.000000e+00  2.430324e-10  0.000000e+00
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     0.000000e+00  0.000000e+00  3.631427e-07  2.492523e-15
# Галина_Ершова       0.000000e+00  0.000000e+00  1.671648e-09  2.960172e-12
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    0.000000e+00  0.000000e+00  0.000000e+00  1.694812e-16
# Иван_Болдырев       8.863763e-13  0.000000e+00  3.502526e-07  6.011403e-05
# Кирилл_Разлогов     0.000000e+00  2.359337e-16  4.110550e-12  3.699695e-06
#
#                             sbj4          sbj5          sbj6          sbj7  \
# Александр_Четверин  3.550547e-14  1.341664e-02  8.532754e-14  0.000000e+00
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     4.843633e-15  0.000000e+00  1.181433e-14  0.000000e+00
# Галина_Ершова       0.000000e+00  1.575471e-16  1.794344e-15  0.000000e+00
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    3.729527e-16  0.000000e+00  1.376835e-16  8.373510e-02
# Иван_Болдырев       1.333018e-07  7.909337e-13  3.144556e-04  8.752134e-08
# Кирилл_Разлогов     9.708191e-09  3.954142e-15  1.501707e-08  2.498720e-10
#
#                             sbj8      sbj9  ...         sbj20         sbj21  \
# Александр_Четверин  3.043732e-05  0.000000  ...  7.189442e-13  5.045514e-10
# Сергей_Деев         1.458348e-02  0.000000  ...  3.109168e-14  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.010587  ...  0.000000e+00  0.000000e+00
# Николай_Борисов     1.936943e-06  0.000000  ...  1.121914e-11  5.433083e-06
# Галина_Ершова       3.174371e-08  0.000000  ...  1.474777e-14  0.000000e+00
# ...                          ...       ...  ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000  ...  3.464595e-02  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000  ...  1.039379e-01  0.000000e+00
# Александр_Гофман    1.689563e-15  0.000000  ...  7.374215e-15  1.537321e-16
# Иван_Болдырев       3.250042e-05  0.000000  ...  3.890079e-04  1.693306e-06
# Кирилл_Разлогов     5.596810e-09  0.000000  ...  2.601191e-03  4.581774e-11
#
#                            sbj22         sbj23         sbj24         sbj25  \
# Александр_Четверин  8.613470e-10  0.000000e+00  0.000000e+00  2.423772e-14
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     2.382453e-11  1.401149e-14  0.000000e+00  0.000000e+00
# Галина_Ершова       0.000000e+00  4.243396e-14  4.787457e-06  0.000000e+00
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Иван_Болдырев       2.461723e-06  1.325750e-07  1.203483e-12  3.135537e-08
# Кирилл_Разлогов     1.484967e-09  1.010286e-06  4.791258e-02  2.833258e-13
#
#                            sbj26         sbj27         sbj28           bcg
# Александр_Четверин  7.353013e-11  1.794466e-06  7.784436e-03  0.000000e+00
# Сергей_Деев         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Роман_Мизюк         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Николай_Борисов     0.000000e+00  6.421392e-10  4.682046e-10  2.939675e-03
# Галина_Ершова       0.000000e+00  0.000000e+00  0.000000e+00  5.829050e-03
# ...                          ...           ...           ...           ...
# Дарья_Радченко      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Алексей_Лебедев     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Александр_Гофман    9.288493e-16  0.000000e+00  0.000000e+00  1.031016e-13
# Иван_Болдырев       5.277478e-10  0.000000e+00  1.472468e-10  1.912690e-03
# Кирилл_Разлогов     5.929048e-12  0.000000e+00  6.441942e-12  1.945048e-06
#
# [539 rows x 30 columns]

# %%
from tqdm import tqdm

rows = []
for topic in tqdm(list(pt.index)):
    row = {"topic": topic}
    for author in list(phi_a.index):
        numerator = phi_a.loc[author][topic] * float(pt.loc[topic])
        denumerator = sum(np.array(phi_a.loc[author]) * np.array(pt[0]))
        row[author] = numerator / denumerator
    rows.append(row)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00
# sbj0              0.0              0.0      0.000000e+00   4.766089e-12
# sbj1              0.0              0.0      0.000000e+00   0.000000e+00
# sbj2              0.0              0.0      0.000000e+00   1.904102e-06
# sbj3              0.0              0.0      2.417730e-15   4.421482e-04
# sbj4              0.0              0.0      4.468200e-15   8.234187e-07
# sbj5              0.0              0.0      0.000000e+00   4.903373e-12
# sbj6              0.0              0.0      1.519683e-15   1.789519e-03
# sbj7              0.0              0.0      1.000000e+00   5.389050e-07
# sbj8              0.0              0.0      5.121468e-14   5.079427e-04
# sbj9              0.0              0.0      0.000000e+00   0.000000e+00
# sbj10             0.0              0.0      0.000000e+00   3.472820e-07
# sbj11             0.0              0.0      0.000000e+00   1.097091e-12
# sbj12             0.0              0.0      0.000000e+00   0.000000e+00
# sbj13             0.0              0.0      0.000000e+00   2.010565e-09
# sbj14             0.0              0.0      0.000000e+00   0.000000e+00
# sbj15             0.0              0.0      0.000000e+00   9.277869e-10
# sbj16             0.0              0.0      0.000000e+00   6.529731e-09
# sbj17             0.0              0.0      0.000000e+00   6.792145e-01
# sbj18             0.0              0.0      0.000000e+00   4.065223e-12
# sbj19             0.0              0.0      1.387538e-14   5.745381e-03
# sbj20             1.0              1.0      8.837580e-14   2.403708e-03
# sbj21             0.0              0.0      1.802271e-15   1.023521e-05
# sbj22             0.0              0.0      0.000000e+00   1.468659e-05
# sbj23             0.0              0.0      0.000000e+00   9.254002e-07
# sbj24             0.0              0.0      0.000000e+00   8.218229e-12
# sbj25             0.0              0.0      0.000000e+00   1.894225e-07
# sbj26             0.0              0.0      1.248171e-14   3.656462e-09
# sbj27             0.0              0.0      0.000000e+00   0.000000e+00
# sbj28             0.0              0.0      0.000000e+00   1.049125e-09
# bcg               0.0              0.0      3.239592e-11   3.098672e-01
#
#        Кирилл_Разлогов
# topic
# sbj0      0.000000e+00
# sbj1      4.423341e-15
# sbj2      6.475216e-11
# sbj3      7.885034e-05
# sbj4      1.737675e-07
# sbj5      7.103177e-14
# sbj6      2.476326e-07
# sbj7      4.458220e-09
# sbj8      2.534614e-07
# sbj9      0.000000e+00
# sbj10     8.724003e-05
# sbj11     9.431604e-07
# sbj12     0.000000e+00
# sbj13     1.471817e-05
# sbj14     0.000000e+00
# sbj15     4.192072e-07
# sbj16     1.313798e-04
# sbj17     0.000000e+00
# sbj18     6.933639e-08
# sbj19     4.123782e-03
# sbj20     4.657374e-02
# sbj21     8.024917e-10
# sbj22     2.567107e-08
# sbj23     2.043420e-05
# sbj24     9.480547e-01
# sbj25     4.959654e-12
# sbj26     1.190324e-10
# sbj27     0.000000e+00
# sbj28     1.329976e-10
# bcg       9.130758e-04
#
# [30 rows x 539 columns]

# %%
mds = MDS(n_components=2, metric="cosine")
pta_transformed = mds.fit_transform(pta)

# %% [markdown]
# Визуализируйте найденные двумерные представления с помощью функции scatter.

# %%
plt.scatter(x=pta_transformed[:, 0], y=pta_transformed[:, 1])
plt.show()

# %% [markdown]
# Должно получиться, что некоторые грппы авторов формируют сгустки, которые можно считать тематическими группами авторов.
#
# Раскрасим точки следующим образом: для каждого автора выберем наиболее вероятную для него тему ($\max_t p(t|a)$), и каждой теме сопоставим цвет. Кроме того, добавим на карту имена и фамилии авторов, это можно сделать в цикле по всем точкам с помощью функции plt.annotate, указывая метку точки первым аргументом и ее координаты в аргументе xy. Рекомендуется сделать размер изображения большим, тогда маркеры точек тоже придется увеличить (s=100 в plt.scatter). Изобразите карту авторов и сохраните в pdf-файл с помощью функции plt.savefig.
#
# Метки авторов будут пересекаться. Будет очень хорошо, если вы найдете способ, как этого можно избежать.

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, T)) # цвета для тем
# Ваш код

# %% [markdown]
# ##### Создание простого тематического навигатора по Постнауке

# %% [markdown]
# Наш тематический навигатор будет для каждой темы показывать ее список слов, а также список релевантных теме документов.
#
# Нам понадобятся распределения $p(d|t)$. По формуле Байеса $p(d|t) = \frac{p(t|d)p(d)}{\sum_{d'}p(t|d')p(d')}$, но поскольку мы считаем документы равновероятными, достаточно разделить каждую строку $\Theta$ на ее сумму, чтобы оценить распределение.
#
# Отсортируйте матрицу $p(d|t)$ по убыванию $p(d|t)$ в каждой теме (то есть построчно). Нам понадобятся индексы наиболее вероятных документов в каждой теме, поэтому используйте функцию argmax.

# %%
# Ваш код

# %% [markdown]
# Создавать навигатор мы будем прямо в jupiter notebook: это возможно благодаря тому факту, что при печати ссылки она автоматически превращается в гиперссылку.

# %%
print "http://yandex.ru"   # получится кликабельная ссылка
# Out:
#   File "/tmp/ipykernel_110163/994542665.py", line 1
#     print "http://yandex.ru"   # получится кликабельная ссылка
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("http://yandex.ru"   # получится кликабельная ссылка)?

# %% [markdown]
# Кроме того, подключив модуль [ipython.core.display](https://ipython.org/ipython-doc/2/api/generated/IPython.core.display.html), можно использовать html-разметку в выводе. Например:

# %%
from IPython.core.display import display, HTML
display(HTML(u"<h1>Заголовок</h1>"))   # также <h2>, <h3>
display(HTML(u"<ul><li>Пункт 1</li><li>Пункт 2</li></ul>"))
display(HTML(u'<font color="green">Зеленый!</font>'))
display(HTML(u'<a href="http://yandex.ru">Еще один вариант вывода ссылки</a>'))

# %% [markdown]
# В цикле для каждой темы выведите ее заголовок, в следующей строке - топ-10 слов темы, затем в виде списка ссылки на 10 наиболее релевантных (по $p(d|t)$) теме документов. Используйте html-разметку. Творчество приветствуется :)

# %%
# Ваш код

# %% [markdown]
# ##### Заключение

# %% [markdown]
# В этом Peer Review мы познакомились с базовыми возможностями библиотеки BigARTM и с методами визуализации тематических моделей. Визуализация тематических моделей - это широкая и активно развивающаяся область научных исследований. Мы рассмотрели только самые простые приемы. Желающие могут попробовать применить [Serendip](http://vep.cs.wisc.edu/serendip/#serendipHero), разработанный в  University of Wisconsin-Madison, к построенной модели. Эта библиотека позволяет максимально полно охарактеризовать темы и написана для языка python.
#
# Сделав задание, вы можете выбрать в навигаторе наиболее интересную для вас тему и посмотреть видеолекции :) На Постнауке очень много интересных материалов.
