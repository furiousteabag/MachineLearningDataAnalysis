# %% [markdown]
# **Корректность проверена на Python 3.6:**
# + gensim 3.4.0

# %% [markdown]
# # Пример использования библиотеки gensim для тематического моделирования

# %% [markdown]
# Такая полезная теорема Байеса! :)
#
# ![comic1](http://imgs.xkcd.com/comics/seashell.png)

# %%
from gensim import corpora, models

# %%
# Импортируем данные в формте UCI Bag of Words
data = corpora.UciCorpus("./data/docword.xkcd.txt", "./data/vocab.xkcd.txt")
dictionary = data.create_dictionary()

# %%
# обучение модель
# %time ldamodel = models.ldamodel.LdaModel(data, id2word=dictionary, num_topics=5, passes=20, alpha=1.25, eta=1.25)
# Out:
# CPU times: user 23.6 s, sys: 61 ms, total: 23.7 s
# Wall time: 23.7 s

# %%
# Сохранение модели
ldamodel.save("./model/ldamodel_xkcd")

# %%
# Загрузка модели
ldamodel = models.ldamodel.LdaModel.load("./model/ldamodel_xkcd")

# %%
# выводим топы слов
for t, top_words in ldamodel.print_topics(num_topics=10, num_words=10):
    print("Topic", t, ":", top_words)
# Out:
# Topic 0 : 0.010*"b'guy'" + 0.005*"b'narrator'" + 0.004*"b'hat'" + 0.004*"b'man'" + 0.004*"b'line'" + 0.003*"b'labeled'" + 0.003*"b'text'" + 0.003*"b'title'" + 0.002*"b'graph'" + 0.002*"b'time'"
# Topic 1 : 0.002*"b'paul'" + 0.001*"b'ron'" + 0.001*"b'han'" + 0.001*"b'elaine'" + 0.001*"b'beef'" + 0.001*"b'mrs'" + 0.001*"b'bag'" + 0.001*"b'leopard'" + 0.001*"b'unallocated'" + 0.001*"b'roberts'"
# Topic 2 : 0.001*"b'reference'" + 0.001*"b'degree'" + 0.001*"b'centigrade'" + 0.001*"b'turtle'" + 0.001*"b'december'" + 0.001*"b'yada'" + 0.001*"b'flu'" + 0.001*"b'google'" + 0.001*"b'accident'" + 0.001*"b'boom'"
# Topic 3 : 0.003*"b'boy'" + 0.001*"b'link'" + 0.001*"b'bean'" + 0.001*"b'jelly'" + 0.001*"b'found'" + 0.001*"b'acne'" + 0.001*"b'goggles'" + 0.001*"b'005'" + 0.001*"b'gliese'" + 0.001*"b'ocean'"
# Topic 4 : 0.022*"b'man'" + 0.012*"b'person'" + 0.012*"b'text'" + 0.010*"b'title'" + 0.009*"b'woman'" + 0.007*"b'one'" + 0.006*"b'girl'" + 0.005*"b'just'" + 0.005*"b'guy'" + 0.005*"b'two'"

# %%
# Вычисляем логарифм перплексии и немного преобразуем, чтобы привести к общепринятому виду
perplexity = ldamodel.log_perplexity(list(data))
print(2**(-perplexity))
# Out:
# 354.13877084457437

# %%
perp = ldamodel.bound(data)
2**(-perp/float(87409))
# Out:
# 354.1387710393717

# %% [raw]
# # Добавление в модель новых документов, содержащихся в новом корупсе data2
# ldamodel.update(data2, passes=10)

# %%
# Получение распределения тем для конкретного документа
doc = list(data)[0]
ldamodel.get_document_topics(doc)
# Out:
# [(0, 0.06437875),
#  (1, 0.0557749),
#  (2, 0.055348005),
#  (3, 0.18898608),
#  (4, 0.6355123)]

# %% [markdown]
# Эти люди не знают про тематические модели:
#
# ![comic2](http://imgs.xkcd.com/comics/the_problem_with_wikipedia.png) | ![comic3](http://imgs.xkcd.com/comics/mystery_news.png)
